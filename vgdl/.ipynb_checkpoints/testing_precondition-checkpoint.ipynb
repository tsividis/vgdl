# %%
class Precondition(object):
	def __init__(self, text, fn):
		self.text = text
		self.fn = fn

	def check(self, arg):
		return self.fn(arg) #1 is dummy arg

	def display(self):
		print self.text

test_p = Precondition('health>1', lambda x: x['health']>1)
b = {'health':1, 'books':1}

# %%
test_p.check(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-a014a2169736> in <module>()
# ----> 1 test_p.check(b)
#
# TypeError: check() takes exactly 1 argument (2 given)
