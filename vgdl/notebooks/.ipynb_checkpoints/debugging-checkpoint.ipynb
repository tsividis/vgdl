# %%
import sys
sys.path.insert(0, '../')

import itertools
import copy
import theory_template_071416 as tt

reload(tt)
# Out:
# explaining events []
# ___________________________________________________________________
# 1 hypotheses:
# _______
#
# InteractionSet:
#
# Class assignments:
# {}
#
# _____________________________________________________________________
#
# explaining events [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')]
# ___________________________________________________________________
# need to add rule!
# need to add rule!
# need to add rule!
# 2 hypotheses:
# _______
#
# InteractionSet:
# collectResource c1 c1
# killSprite c1 c1
#
# Class assignments:
# {'c1': ['DARKBLUE', 'RED']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
#
# Class assignments:
# {'c2': ['RED'], 'c1': ['DARKBLUE']}
#
# _____________________________________________________________________
#
# explaining events [('killSprite', 'DARKBLUE', 'BLUE')]
# ___________________________________________________________________
# need to add rule!
# need to add rule!
# 3 hypotheses:
# _______
#
# InteractionSet:
# collectResource c1 c1
# killSprite c1 c1
# killSprite c1 c2
#
# Class assignments:
# {'c2': ['BLUE'], 'c1': ['DARKBLUE', 'RED']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c1
#
# Class assignments:
# {'c2': ['RED'], 'c1': ['DARKBLUE', 'BLUE']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c3
#
# Class assignments:
# {'c3': ['BLUE'], 'c2': ['RED'], 'c1': ['DARKBLUE']}
#
# _____________________________________________________________________
#
# explaining events [('bounceForward', 'DARKBLUE', 'PINK')]
# ___________________________________________________________________
# need to add rule!
# need to add rule!
# need to add rule!
# 4 hypotheses:
# _______
#
# InteractionSet:
# collectResource c1 c1
# killSprite c1 c1
# killSprite c1 c2
# bounceForward c1 c3
#
# Class assignments:
# {'c3': ['PINK'], 'c2': ['BLUE'], 'c1': ['DARKBLUE', 'RED']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c3
# bounceForward c1 c1
#
# Class assignments:
# {'c3': ['BLUE'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'PINK']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c1
# bounceForward c1 c3
#
# Class assignments:
# {'c3': ['PINK'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'BLUE']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c3
# bounceForward c1 c4
#
# Class assignments:
# {'c3': ['BLUE'], 'c2': ['RED'], 'c1': ['DARKBLUE'], 'c4': ['PINK']}
#
# _____________________________________________________________________
#
# explaining events [('bounceForward', 'DARKBLUE', 'ORANGE')]
# ___________________________________________________________________
# need to add rule!
# need to add rule!
# need to add rule!
# need to add rule!
# 9 hypotheses:
# _______
#
# InteractionSet:
# collectResource c1 c1
# killSprite c1 c1
# killSprite c1 c2
# bounceForward c1 c3
#
# Class assignments:
# {'c3': ['PINK', 'ORANGE'], 'c2': ['BLUE'], 'c1': ['DARKBLUE', 'RED']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c1
# bounceForward c1 c3
#
# Class assignments:
# {'c3': ['PINK', 'ORANGE'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'BLUE']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c3
# bounceForward c1 c1
#
# Class assignments:
# {'c3': ['BLUE'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'PINK', 'ORANGE']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c3
# bounceForward c1 c4
#
# Class assignments:
# {'c3': ['BLUE'], 'c2': ['RED'], 'c1': ['DARKBLUE'], 'c4': ['PINK', 'ORANGE']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c1
# bounceForward c1 c3
# bounceForward c1 c4
#
# Class assignments:
# {'c3': ['PINK'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'BLUE'], 'c4': ['ORANGE']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c3
# bounceForward c1 c1
# bounceForward c1 c4
#
# Class assignments:
# {'c3': ['BLUE'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'PINK'], 'c4': ['ORANGE']}
#
# _______
#
# InteractionSet:
# collectResource c1 c1
# killSprite c1 c1
# killSprite c1 c2
# bounceForward c1 c3
# bounceForward c1 c4
#
# Class assignments:
# {'c3': ['PINK'], 'c2': ['BLUE'], 'c1': ['DARKBLUE', 'RED'], 'c4': ['ORANGE']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c3
# bounceForward c1 c4
# bounceForward c1 c1
#
# Class assignments:
# {'c3': ['BLUE'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'ORANGE'], 'c4': ['PINK']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c3
# bounceForward c1 c4
# bounceForward c1 c5
#
# Class assignments:
# {'c3': ['BLUE'], 'c2': ['RED'], 'c1': ['DARKBLUE'], 'c5': ['ORANGE'], 'c4': ['PINK']}
#
# _____________________________________________________________________
#
# explaining events [('bounceForward', 'DARKBLUE', 'PINK')]
# ___________________________________________________________________
# 9 hypotheses:
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c1
# bounceForward c1 c3
#
# Class assignments:
# {'c3': ['PINK', 'ORANGE'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'BLUE']}
#
# _______
#
# InteractionSet:
# collectResource c1 c1
# killSprite c1 c1
# killSprite c1 c2
# bounceForward c1 c3
#
# Class assignments:
# {'c3': ['PINK', 'ORANGE'], 'c2': ['BLUE'], 'c1': ['DARKBLUE', 'RED']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c3
# bounceForward c1 c1
#
# Class assignments:
# {'c3': ['BLUE'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'PINK', 'ORANGE']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c3
# bounceForward c1 c4
#
# Class assignments:
# {'c3': ['BLUE'], 'c2': ['RED'], 'c1': ['DARKBLUE'], 'c4': ['PINK', 'ORANGE']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c1
# bounceForward c1 c3
# bounceForward c1 c4
#
# Class assignments:
# {'c3': ['PINK'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'BLUE'], 'c4': ['ORANGE']}
#
# _______
#
# InteractionSet:
# collectResource c1 c1
# killSprite c1 c1
# killSprite c1 c2
# bounceForward c1 c3
# bounceForward c1 c4
#
# Class assignments:
# {'c3': ['PINK'], 'c2': ['BLUE'], 'c1': ['DARKBLUE', 'RED'], 'c4': ['ORANGE']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c3
# bounceForward c1 c1
# bounceForward c1 c4
#
# Class assignments:
# {'c3': ['BLUE'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'PINK'], 'c4': ['ORANGE']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c3
# bounceForward c1 c4
# bounceForward c1 c1
#
# Class assignments:
# {'c3': ['BLUE'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'ORANGE'], 'c4': ['PINK']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c3
# bounceForward c1 c4
# bounceForward c1 c5
#
# Class assignments:
# {'c3': ['BLUE'], 'c2': ['RED'], 'c1': ['DARKBLUE'], 'c5': ['ORANGE'], 'c4': ['PINK']}
#
# _____________________________________________________________________
#
# explaining events [('killSprite', 'DARKBLUE', 'GOLD')]
# ___________________________________________________________________
# need to add rule!
# need to add rule!
# need to add rule!
# need to add rule!
# need to add rule!
# need to add rule!
# need to add rule!
# need to add rule!
# need to add rule!
# 20 hypotheses:
# _______
#
# InteractionSet:
# collectResource c1 c1
# killSprite c1 c1
# killSprite c1 c2
# bounceForward c1 c3
#
# Class assignments:
# {'c3': ['PINK', 'ORANGE'], 'c2': ['BLUE', 'GOLD'], 'c1': ['DARKBLUE', 'RED']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c3
# bounceForward c1 c1
#
# Class assignments:
# {'c3': ['BLUE', 'GOLD'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'PINK', 'ORANGE']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c1
# bounceForward c1 c3
#
# Class assignments:
# {'c3': ['PINK', 'ORANGE'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'BLUE', 'GOLD']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c3
# bounceForward c1 c4
#
# Class assignments:
# {'c3': ['BLUE', 'GOLD'], 'c2': ['RED'], 'c1': ['DARKBLUE'], 'c4': ['PINK', 'ORANGE']}
#
# _______
#
# InteractionSet:
# collectResource c1 c1
# killSprite c1 c1
# killSprite c1 c2
# bounceForward c1 c3
# killSprite c1 c4
#
# Class assignments:
# {'c3': ['PINK', 'ORANGE'], 'c2': ['BLUE'], 'c1': ['DARKBLUE', 'RED'], 'c4': ['GOLD']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c3
# bounceForward c1 c4
# killSprite c1 c1
#
# Class assignments:
# {'c3': ['BLUE'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'GOLD'], 'c4': ['PINK', 'ORANGE']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c1
# bounceForward c1 c3
# killSprite c1 c4
#
# Class assignments:
# {'c3': ['PINK', 'ORANGE'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'BLUE'], 'c4': ['GOLD']}
#
# _______
#
# InteractionSet:
# collectResource c1 c1
# killSprite c1 c1
# killSprite c1 c2
# bounceForward c1 c3
# bounceForward c1 c4
#
# Class assignments:
# {'c3': ['PINK'], 'c2': ['BLUE', 'GOLD'], 'c1': ['DARKBLUE', 'RED'], 'c4': ['ORANGE']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c3
# bounceForward c1 c1
# bounceForward c1 c4
#
# Class assignments:
# {'c3': ['BLUE', 'GOLD'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'PINK'], 'c4': ['ORANGE']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c3
# bounceForward c1 c4
# bounceForward c1 c1
#
# Class assignments:
# {'c3': ['BLUE', 'GOLD'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'ORANGE'], 'c4': ['PINK']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c1
# bounceForward c1 c3
# bounceForward c1 c4
#
# Class assignments:
# {'c3': ['PINK'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'BLUE', 'GOLD'], 'c4': ['ORANGE']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c3
# bounceForward c1 c1
# killSprite c1 c4
#
# Class assignments:
# {'c3': ['BLUE'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'PINK', 'ORANGE'], 'c4': ['GOLD']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c3
# bounceForward c1 c4
# killSprite c1 c5
#
# Class assignments:
# {'c3': ['BLUE'], 'c2': ['RED'], 'c1': ['DARKBLUE'], 'c5': ['GOLD'], 'c4': ['PINK', 'ORANGE']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c3
# bounceForward c1 c4
# bounceForward c1 c5
#
# Class assignments:
# {'c3': ['BLUE', 'GOLD'], 'c2': ['RED'], 'c1': ['DARKBLUE'], 'c5': ['ORANGE'], 'c4': ['PINK']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c3
# bounceForward c1 c4
# bounceForward c1 c5
# killSprite c1 c1
#
# Class assignments:
# {'c3': ['BLUE'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'GOLD'], 'c5': ['ORANGE'], 'c4': ['PINK']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c3
# bounceForward c1 c4
# bounceForward c1 c1
# killSprite c1 c5
#
# Class assignments:
# {'c3': ['BLUE'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'ORANGE'], 'c5': ['GOLD'], 'c4': ['PINK']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c1
# bounceForward c1 c3
# bounceForward c1 c4
# killSprite c1 c5
#
# Class assignments:
# {'c3': ['PINK'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'BLUE'], 'c5': ['GOLD'], 'c4': ['ORANGE']}
#
# _______
#
# InteractionSet:
# collectResource c1 c1
# killSprite c1 c1
# killSprite c1 c2
# bounceForward c1 c3
# bounceForward c1 c4
# killSprite c1 c5
#
# Class assignments:
# {'c3': ['PINK'], 'c2': ['BLUE'], 'c1': ['DARKBLUE', 'RED'], 'c5': ['GOLD'], 'c4': ['ORANGE']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c3
# bounceForward c1 c1
# bounceForward c1 c4
# killSprite c1 c5
#
# Class assignments:
# {'c3': ['BLUE'], 'c2': ['RED'], 'c1': ['DARKBLUE', 'PINK'], 'c5': ['GOLD'], 'c4': ['ORANGE']}
#
# _______
#
# InteractionSet:
# collectResource c1 c2
# killSprite c1 c2
# killSprite c1 c3
# bounceForward c1 c4
# bounceForward c1 c5
# killSprite c1 c6
#
# Class assignments:
# {'c3': ['BLUE'], 'c2': ['RED'], 'c1': ['DARKBLUE'], 'c6': ['GOLD'], 'c5': ['ORANGE'], 'c4': ['PINK']}
#
# _____________________________________________________________________
# <module 'theory_template_071416' from '../theory_template_071416.pyc'>

# %%
## Debugging equality of theories
# g0 = tt.Game()
# t0 = tt.Theory(g0)
# t1 = tt.Theory(g0)

# i1 = tt.InteractionRule('killSprite', 'c1', 'c2')
# i2 = tt.InteractionRule('killSprite', 'c1', 'c2')
# i3 = tt.InteractionRule('killSprite', 'c2', 'c2')

# t0.classes = {'c1': ['BLACK'], 'c2': ['BLUE']}
# t0.interactionSet = [i1]
# t0.predicates = ['killSprite']

# t1.classes = {'c1': ['BLACK'], 'c2': ['BLUE']}
# t1.interactionSet = [i2]
# t1.predicates = ['killSprite']

# print "Theory equality:"
# print "Classes equal? {}".format(t0.classes == t1.classes)
# print "InteractionSet equal? {}".format(t0.interactionSet==t1.interactionSet)
# print "Predicates equal? {}".format(t0.predicates == t1.predicates)
# print "Equality overall?", t1==t0

# print "\n\nInteractionRule equality:"
# print "Tuple?", i1.asTuple()==i2.asTuple()
# print "Preconditions?", i1.preconditions==i2.preconditions
# print "Object type?", isinstance(i2, i1.__class__)
# print "Equality check?", i1==i2
# print "\n\n\n"

## Testing induction for equality -- DONE!
# g = tt.Game()
# rawTrace = [
# {'agentAction': 'up', 'agentState': {}, 'effectList': [('bounceForward', 'DARKBLUE', 'ORANGE')]}, 
# {'agentAction': 'up', 'agentState': {}, 'effectList': [('bounceForward', 'DARKBLUE', 'ORANGE'), ('undoAll', 'ORANGE', 'BLACK')]}, 
# {'agentAction': 'right', 'agentState': {}, 'effectList': [('bounceForward', 'DARKBLUE', 'ORANGE')]}, 
# {'agentAction': 'up', 'agentState': {}, 'effectList': [('changeResource', 'DARKBLUE', 'WHITE'), ('killSprite', 'DARKBLUE', 'WHITE')]}
# ]

# trace = [TimeStep(tr['agentAction'], tr['agentState'], tr['effectList']) for tr in rawTrace]
# hypotheses=list(g.induction(trace))

# %%
## Debugging preconditions
g = tt.Game()
rawTrace = [
{'agentAction': None, 'agentState': {}, 'effectList': []}, 
{'agentAction': None, 'agentState': {}, 'effectList': [('killSprite', 'DARKBLUE', 'BLUE')]}, 
{'agentAction': None, 'agentState': {'trap': 1}, 'effectList': [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')]}, 
{'agentAction': None, 'agentState': {'trap': 1}, 'effectList': [('bounceForward', 'DARKBLUE', 'BLUE')]}, 
{'agentAction': None, 'agentState': {'trap': 1}, 'effectList': [('bounceForward', 'DARKBLUE', 'ORANGE')]}, 
{'agentAction': None, 'agentState': {'trap': 1}, 'effectList': [('killSprite', 'DARKBLUE', 'GOLD')]}
]

trace = [tt.TimeStep(tr['agentAction'], tr['agentState'], tr['effectList']) for tr in rawTrace]
hypotheses=list(g.induction(trace))
# Out:
# explaining events []
# ___________________________________________________________________
# 1 hypotheses:
# _______
#
# InteractionSet:
#
# Class assignments:
# {}
#
# _____________________________________________________________________
#
# explaining events [('killSprite', 'DARKBLUE', 'BLUE')]
# ___________________________________________________________________
# need to add rule!
# 2 hypotheses:
# _______
#
# InteractionSet:
# killSprite c1 c1 ['trap>0']
#
# Class assignments:
# {'c1': ['DARKBLUE', 'BLUE']}
#
# _______
#
# InteractionSet:
# killSprite c1 c2 ['trap>0']
#
# Class assignments:
# {'c2': ['BLUE'], 'c1': ['DARKBLUE']}
#
# _____________________________________________________________________
#
# explaining events [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')]
# ___________________________________________________________________
# need to add rule!
# need to add rule!
# need to add rule!
# need to add rule!
# need to add rule!
# 3 hypotheses:
# _______
#
# InteractionSet:
# killSprite c1 c1 ['trap>0']
# collectResource c1 c2 ['trap>0']
# killSprite c1 c2 ['trap>0']
#
# Class assignments:
# {'c2': ['RED'], 'c1': ['DARKBLUE', 'BLUE']}
#
# _______
#
# InteractionSet:
# killSprite c1 c2 ['trap>0']
# collectResource c1 c1 ['trap>0']
# killSprite c1 c1 ['trap>0']
#
# Class assignments:
# {'c2': ['BLUE'], 'c1': ['DARKBLUE', 'RED']}
#
# _______
#
# InteractionSet:
# killSprite c1 c2 ['trap>0']
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLUE'], 'c1': ['DARKBLUE']}
#
# _____________________________________________________________________
#
# explaining events [('bounceForward', 'DARKBLUE', 'BLUE')]
# ___________________________________________________________________
# need to add precondition!
# killSprite c1 c1 ['not trap>0']
# _______
#
# InteractionSet:
# killSprite c1 c1 ['not trap>0']
# collectResource c1 c2 ['trap>0']
# killSprite c1 c2 ['trap>0']
# bounceForward c1 c1 ['trap>0']
#
# Class assignments:
# {'c2': ['RED'], 'c1': ['DARKBLUE', 'BLUE']}
#
# need to add precondition!
# killSprite c1 c2 ['not trap>0']
# _______
#
# InteractionSet:
# killSprite c1 c2 ['not trap>0']
# collectResource c1 c3 ['trap>0']
# killSprite c1 c3 ['trap>0']
# bounceForward c1 c2 ['trap>0']
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLUE'], 'c1': ['DARKBLUE']}
#
# need to add precondition!
# killSprite c1 c2 ['not trap>0']
# _______
#
# InteractionSet:
# killSprite c1 c2 ['not trap>0']
# collectResource c1 c1 ['trap>0']
# killSprite c1 c1 ['trap>0']
# bounceForward c1 c2 ['trap>0']
#
# Class assignments:
# {'c2': ['BLUE'], 'c1': ['DARKBLUE', 'RED']}
#
# 0 hypotheses:
# _____________________________________________________________________
#
# explaining events [('bounceForward', 'DARKBLUE', 'ORANGE')]
# ___________________________________________________________________
# 0 hypotheses:
# _____________________________________________________________________
#
# explaining events [('killSprite', 'DARKBLUE', 'GOLD')]
# ___________________________________________________________________
# 0 hypotheses:
# _____________________________________________________________________
