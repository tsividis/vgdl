# %%
import sys
sys.path.insert(0, '../')

import itertools
import copy
import theory_template_071416 as tt

reload(tt)
# Out:
# <module 'theory_template_071416' from '../theory_template_071416.py'>

# %%
## Debugging equality of theories
# g0 = tt.Game()
# t0 = tt.Theory(g0)
# t1 = tt.Theory(g0)

# i1 = tt.InteractionRule('killSprite', 'c1', 'c2')
# i2 = tt.InteractionRule('killSprite', 'c1', 'c2')
# i3 = tt.InteractionRule('killSprite', 'c2', 'c2')

# t0.classes = {'c1': ['BLACK'], 'c2': ['BLUE']}
# t0.interactionSet = [i1]
# t0.predicates = ['killSprite']

# t1.classes = {'c1': ['BLACK'], 'c2': ['BLUE']}
# t1.interactionSet = [i2]
# t1.predicates = ['killSprite']

# print "Theory equality:"
# print "Classes equal? {}".format(t0.classes == t1.classes)
# print "InteractionSet equal? {}".format(t0.interactionSet==t1.interactionSet)
# print "Predicates equal? {}".format(t0.predicates == t1.predicates)
# print "Equality overall?", t1==t0

# print "\n\nInteractionRule equality:"
# print "Tuple?", i1.asTuple()==i2.asTuple()
# print "Preconditions?", i1.preconditions==i2.preconditions
# print "Object type?", isinstance(i2, i1.__class__)
# print "Equality check?", i1==i2
# print "\n\n\n"

## Testing induction for equality -- DONE!
# g = tt.Game()
# rawTrace = [
# {'agentAction': 'up', 'agentState': {}, 'effectList': [('bounceForward', 'DARKBLUE', 'ORANGE')]}, 
# {'agentAction': 'up', 'agentState': {}, 'effectList': [('bounceForward', 'DARKBLUE', 'ORANGE'), ('undoAll', 'ORANGE', 'BLACK')]}, 
# {'agentAction': 'right', 'agentState': {}, 'effectList': [('bounceForward', 'DARKBLUE', 'ORANGE')]}, 
# {'agentAction': 'up', 'agentState': {}, 'effectList': [('changeResource', 'DARKBLUE', 'WHITE'), ('killSprite', 'DARKBLUE', 'WHITE')]}
# ]

# trace = [TimeStep(tr['agentAction'], tr['agentState'], tr['effectList']) for tr in rawTrace]
# hypotheses=list(g.induction(trace))

# %%
## Debugging preconditions
g = tt.Game()
rawTrace = [ 
{'agentAction': None, 'agentState': {}, 'effectList': [('killSprite', 'DARKBLUE', 'BLUE')]}, 
{'agentAction': None, 'agentState': {'trap': 1}, 'effectList': [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')]}, 
{'agentAction': None, 'agentState': {'trap': 1}, 'effectList': [('bounceForward', 'DARKBLUE', 'BLUE')]}, 
{'agentAction': None, 'agentState': {'trap': 1}, 'effectList': [('bounceForward', 'DARKBLUE', 'ORANGE')]}, 
{'agentAction': None, 'agentState': {'trap': 1}, 'effectList': [('killSprite', 'DARKBLUE', 'GOLD')]}
]

trace = [tt.TimeStep(tr['agentAction'], tr['agentState'], tr['effectList']) for tr in rawTrace]

hypotheses=list(g.induction(trace))
# Out:
# explaining events [('killSprite', 'DARKBLUE', 'BLUE')]
# ___________________________________________________________________
#
# events are in rules False
# predictions happened
# False
# In base case of explainTimeStep...
# In explainEvent, checking event ('killSprite', 'DARKBLUE', 'BLUE'), with ruleset
# 	[]
#
# events are in rules False
# predictions happened
# False
# Will add a rule.
#
# events are in rules True
# predictions happened
# True
# [True]
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
# [False]
#
# events are in rules False
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
# [True]
#
# events are in rules True
# predictions happened
# True
# 2 hypotheses:
# _______
#
# InteractionSet:
# killSprite c1 c1
#
# Class assignments:
# {'c1': ['DARKBLUE', 'BLUE']}
#
# _______
#
# InteractionSet:
# killSprite c1 c2
#
# Class assignments:
# {'c2': ['BLUE'], 'c1': ['DARKBLUE']}
#
# ___________________________________________________________________
#
# explaining events [('collectResource', 'DARKBLUE', 'RED'), ('killSprite', 'DARKBLUE', 'RED')]
# ___________________________________________________________________
#
# events are in rules False
# predictions happened
# False
# Recursing in explainTimeStep...
# In explainEvent, checking event ('collectResource', 'DARKBLUE', 'RED'), with ruleset
# 	killSprite c1 c2
# [None]
#
# events are in rules False
# predictions happened
# False
# Will add a rule.
# In base case of explainTimeStep...
# In explainEvent, checking event ('killSprite', 'DARKBLUE', 'RED'), with ruleset
# 	killSprite c1 c2
# collectResource c1 c2
# [None, None]
#
# events are in rules True
# predictions happened
# True
# In explainEvent, checking event ('killSprite', 'DARKBLUE', 'RED'), with ruleset
# 	killSprite c1 c2
# collectResource c1 c1
# [None, None]
#
# events are in rules False
# predictions happened
# True
# Will add a rule.
# In explainEvent, checking event ('killSprite', 'DARKBLUE', 'RED'), with ruleset
# 	killSprite c1 c2
# collectResource c1 c3
# [None, None]
#
# events are in rules False
# predictions happened
# True
# Will add a rule.
#
# events are in rules False
# predictions happened
# False
# Recursing in explainTimeStep...
# In explainEvent, checking event ('collectResource', 'DARKBLUE', 'RED'), with ruleset
# 	killSprite c1 c1
# [None]
#
# events are in rules False
# predictions happened
# False
# Will add a rule.
# In base case of explainTimeStep...
# In explainEvent, checking event ('killSprite', 'DARKBLUE', 'RED'), with ruleset
# 	killSprite c1 c1
# collectResource c1 c1
# [None, None]
#
# events are in rules True
# predictions happened
# True
# In explainEvent, checking event ('killSprite', 'DARKBLUE', 'RED'), with ruleset
# 	killSprite c1 c1
# collectResource c1 c2
# [None, None]
#
# events are in rules False
# predictions happened
# True
# Will add a rule.
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
# [True, True]
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
# [True, False]
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
# [True, False]
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
# [True, True]
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
# [True, True]
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
# [False, True]
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
# [False, True]
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
# 3 hypotheses:
# _______
#
# InteractionSet:
# killSprite c1 c2
# collectResource c1 c1
# killSprite c1 c1
#
# Class assignments:
# {'c2': ['BLUE'], 'c1': ['DARKBLUE', 'RED']}
#
# _______
#
# InteractionSet:
# killSprite c1 c1
# collectResource c1 c2
# killSprite c1 c2
#
# Class assignments:
# {'c2': ['RED'], 'c1': ['DARKBLUE', 'BLUE']}
#
# _______
#
# InteractionSet:
# killSprite c1 c2
# collectResource c1 c3
# killSprite c1 c3
#
# Class assignments:
# {'c3': ['RED'], 'c2': ['BLUE'], 'c1': ['DARKBLUE']}
#
# ___________________________________________________________________
#
# explaining events [('bounceForward', 'DARKBLUE', 'BLUE')]
# ___________________________________________________________________
#
# events are in rules False
# predictions happened
# False
# In base case of explainTimeStep...
# In explainEvent, checking event ('bounceForward', 'DARKBLUE', 'BLUE'), with ruleset
# 	killSprite c1 c2
# collectResource c1 c1
# killSprite c1 c1
# [None, None, None]
#
# events are in rules False
# predictions happened
# False
# Will add a precondition.
#
# events are in rules False
# predictions happened
# False
# In base case of explainTimeStep...
# In explainEvent, checking event ('bounceForward', 'DARKBLUE', 'BLUE'), with ruleset
# 	killSprite c1 c2
# collectResource c1 c3
# killSprite c1 c3
# [None, None, None]
#
# events are in rules False
# predictions happened
# False
# Will add a precondition.
#
# events are in rules False
# predictions happened
# False
# In base case of explainTimeStep...
# In explainEvent, checking event ('bounceForward', 'DARKBLUE', 'BLUE'), with ruleset
# 	killSprite c1 c1
# collectResource c1 c2
# killSprite c1 c2
# [None, None, None]
#
# events are in rules False
# predictions happened
# False
# Will add a precondition.
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# True
# [True, True, False]
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# True
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
# [False, True, True]
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
# [False, True, True]
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
# [True, False, False]
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
# [True, False, False]
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# True
# [True, True, False]
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# True
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
# [False, True, True]
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# True
# [True, True, False]
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# True
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
# [False, True, False]
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
# [False, True, False]
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
# 0 hypotheses:
# ___________________________________________________________________
#
# explaining events [('bounceForward', 'DARKBLUE', 'ORANGE')]
# ___________________________________________________________________
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
# [True, True, False, False]
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
# [False, True, True, False]
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
# [False, True, True, False]
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
# [True, False, False, False]
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
# [True, False, False, False]
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
# [True, True, False, False]
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
# [False, True, True, False]
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
# [True, True, False, False]
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
# [False, True, False, False]
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
# [False, True, False, False]
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
# 0 hypotheses:
# ___________________________________________________________________
#
# explaining events [('killSprite', 'DARKBLUE', 'GOLD')]
# ___________________________________________________________________
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
# [True, True, False, False, False]
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
# [False, True, True, False, False]
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
# [False, True, True, False, False]
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
# [True, False, False, False, False]
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
# [True, False, False, False, False]
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
# [True, True, False, False, False]
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
# [False, True, True, False, False]
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
# [True, True, False, False, False]
#
# events are in rules True
# predictions happened
# True
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
# [False, True, False, False, False]
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
# [False, True, False, False, False]
#
# events are in rules True
# predictions happened
# False
#
# events are in rules True
# predictions happened
# True
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
#
# events are in rules False
# predictions happened
# False
# 0 hypotheses:
# ___________________________________________________________________
