# %%
import itertools

# %%
lst = ['city', 'bullet', 'avatar', 'enemy_slow', 'enemy_fast', 'niceGuy', 'death', 'enemySlowPortal', 'enemyFastPortal' 
list(itertools.combinations(lst, 2))
# Out:
#   File "<ipython-input-2-b02ba8ab33fd>", line 1
#     lst = [‘citizen’, ‘blessed’, ‘wall’, ‘box’, …]
#                    ^
# SyntaxError: invalid character in identifier
