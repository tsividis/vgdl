# %%
import numpy as np
import math
import os 
import matplotlib.pyplot as plt
import csv
import scipy.stats
import sklearn.metrics.pairwise as k

# %%
import HRR
reload(HRR)
# Out:
# <module 'HRR' from 'HRR.py'>

# %%
rm, rsem, rs, game_names = HRR.sanity()
# Out:
# ERROR:root:there shouldn't be EOS
# ERROR:root:NO SUCH SPRITE rand
# ERROR:root:NO SUCH SPRITE missile
# ERROR:root:NO SUCH SPRITE missile
# ERROR:root:NO SUCH SPRITE missile
# ERROR:root:NO SUCH SPRITE rand
# ERROR:root:NO SUCH SPRITE missile
# ERROR:root:NO SUCH SPRITE missile
# ERROR:root:NO SUCH SPRITE missile
# ERROR:root:NO SPRITE TYPE[u'enemy', u'>']
# ERROR:root:there shouldn't be EOS
# ERROR:root:NO SUCH SPRITE rand
# ERROR:root:NO SUCH SPRITE missile
# ERROR:root:NO SUCH SPRITE missile
# ERROR:root:NO SUCH SPRITE missile
# ERROR:root:NO SUCH SPRITE rand
# ERROR:root:NO SUCH SPRITE missile
# ERROR:root:NO SUCH SPRITE missile
# ERROR:root:NO SUCH SPRITE missile
# ERROR:root:NO SPRITE TYPE[u'enemy', u'>']
# ERROR:root:there shouldn't be EOS
# ERROR:root:NO SUCH SPRITE rand
# ERROR:root:NO SUCH SPRITE missile
# ERROR:root:NO SUCH SPRITE missile
# ERROR:root:NO SUCH SPRITE missile
# ERROR:root:NO SUCH SPRITE rand
# ERROR:root:NO SUCH SPRITE missile
# ...

# %%
import matplotlib.pyplot as plt


r = rs.reshape((-1, 49)).T

plt.figure(dpi=800, figsize=(8, 8))
fig, ax = plt.subplots(figsize=(20,20))

ax.violinplot(r[:,:2])

#plt.show()
# Out:
# {u'bodies': [<matplotlib.collections.PolyCollection at 0x101e73bd0>,
# ...
#  u'cbars': <matplotlib.collections.LineCollection at 0x11d03ec90>,
#  u'cmaxes': <matplotlib.collections.LineCollection at 0x11cfc5ed0>,
#  u'cmins': <matplotlib.collections.LineCollection at 0x11d03ead0>}

# %%
import matplotlib.pyplot as plt
 
labels = game_names
 
plt.figure(dpi=800, figsize=(8, 8))
fig, ax = plt.subplots(figsize=(20,20))
cax = ax.matshow(rm, interpolation='nearest')
ax.grid(True)
plt.title('HRR confusion matrix (Pearson correlation)')
plt.xticks(range(len(labels)), labels, rotation=90);
plt.yticks(range(len(labels)), labels);
fig.colorbar(cax)
plt.show()
